# %%
from leer_datos import leer_fichero
vuelos = leer_fichero("Cleaned_2018_Flights.csv")
# import pickle
# with open("vuelos.obj", "rb") as fh:
#     vuelos = pickle.load(fh)

# %%
print(len(vuelos))
# Out:
# 1000

# %%
from Arbol import Arbol
arbol = Arbol(["origen", "destino","trimestre", "compania"])
for vuelo in vuelos:
    nodo_final = arbol.insertar_vuelo(vuelo)
    
# print(len(nodo_final.vuelos))
# nodo_final.vuelos

# %%
# from Vuelo import Vuelo
# arbol.insertar_vuelo(Vuelo("OJIDS", "aosdijf", 234.324, "OIF", 32, 1))

# %%
arbol.mostrar()
# Out:
# ->PHL->LAX->1->AA
# ->PHL->LGA->1->AA
# ->PHL->BOS->1->AA
# ->PHL->RDU->1->AA
# ->PHL->MCI->1->AA
# ->LAX->ORD->1->AA
# ->LAX->PHL->1->AA
# ->SAN->JFK->1->AA
# ->SFO->PHL->1->AA
# ->SFO->JFK->1->AA
# ->AUS->PHL->1->AA
# ->BOS->PHL->1->AA
# ->MIA->PHL->1->AA
# ->ORD->PHL->1->AA
# ->LGA->PHL->1->AA
# ->CLT->TPA->1->AA
# ->TPA->PHL->1->AA
# ->DFW->PHL->1->AA
# ->LAS->PHL->1->AA
# ->MCI->PHL->1->AA

# %%
len(arbol.buscar(["PHL","LAX",1,"AA"]))
# Out:
# 414

# %%
from quicksort import quickSort
quickSort(vuelos)
# Out:
# [Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 67.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 67.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 67.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 67.5, km = 3867.22),
#  Vuelo(origen = CLT, destino = TPA, trimestre = 1, compañía = AA, precio = 80.24, km = 816.27),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 104.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 104.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 109.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 109.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 111.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 111.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 116.95, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 118.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 118.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 119.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 119.0, km = 3867.22),
#  Vuelo(origen = BOS, destino = PHL, trimestre = 1, compañía = AA, precio = 120.71, km = 450.8),
#  Vuelo(origen = PHL, destino = BOS, trimestre = 1, compañía = AA, precio = 122.0, km = 450.8),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 126.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 126.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 129.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 129.0, km = 3867.22),
#  Vuelo(origen = ORD, destino = PHL, trimestre = 1, compañía = AA, precio = 130.92, km = 1091.58),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 131.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 131.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 132.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 132.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 133.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 133.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 133.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 133.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 134.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 134.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 135.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 135.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 136.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 136.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 137.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 137.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 137.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 137.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 138.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 138.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 138.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 138.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 138.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 138.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 139.25, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 140.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 140.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 141.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 141.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 141.0, km = 154.56),
#  Vuelo(origen = LGA, destino = PHL, trimestre = 1, compañía = AA, precio = 141.0, km = 154.56),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 143.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 143.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 143.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 143.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 144.4, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 145.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 145.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = RDU, trimestre = 1, compañía = AA, precio = 145.29, km = 542.57),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 145.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 145.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 145.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 145.5, km = 3867.22),
#  Vuelo(origen = TPA, destino = PHL, trimestre = 1, compañía = AA, precio = 145.6, km = 1481.2),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 147.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 147.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 148.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 148.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 150.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 150.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 151.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 151.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 151.78, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 152.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 152.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 153.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 153.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 154.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 154.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 155.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 155.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 156.35, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 157.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 157.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 158.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 158.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 158.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 158.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 159.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 159.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 159.83, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 160.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 160.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 160.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 160.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 161.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 161.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 161.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 161.5, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 161.82, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 162.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 162.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 162.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 162.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 163.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 163.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 163.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 163.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 163.04, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 163.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 163.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 163.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 163.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 164.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 164.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 164.28, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 165.08, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 165.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 165.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 165.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 165.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 165.57, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 166.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 166.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 166.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 166.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 167.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 167.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 167.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 167.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 167.81, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 168.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 168.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 168.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 168.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 168.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 168.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 169.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 169.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 169.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 169.98, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 170.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 170.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 171.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 172.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 172.28, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 172.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 172.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 173.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 173.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 173.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 173.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 174.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 174.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 174.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 174.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 174.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 174.58, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 175.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 175.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 175.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 175.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 176.39, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 176.76, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 177.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 177.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 177.26, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 178.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 178.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 178.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 178.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 178.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 178.65, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 179.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 179.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 179.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 179.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 179.19, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 179.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 179.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 179.58, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 179.58, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 180.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 180.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 180.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 180.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 180.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 180.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 180.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 180.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 180.46, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 180.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 180.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 180.75, km = 3867.22),
#  Vuelo(origen = LGA, destino = PHL, trimestre = 1, compañía = AA, precio = 181.0, km = 154.56),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 181.65, km = 4058.81),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 182.27, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 182.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 182.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 183.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 183.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 183.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 183.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 183.5, km = 3867.22),
#  Vuelo(origen = SAN, destino = JFK, trimestre = 1, compañía = AA, precio = 183.65, km = 3938.06),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 183.7, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 185.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 185.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 185.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 185.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 185.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 185.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 186.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 186.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 187.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 187.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 187.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 187.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 188.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 188.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 188.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 188.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 188.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 188.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 188.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 188.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 188.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 189.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 189.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 189.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 189.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 190.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 190.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 190.06, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 190.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 190.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 191.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 191.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 191.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 191.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 191.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 191.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 191.5, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 193.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 193.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 193.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 193.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 193.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 193.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 194.54, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 195.19, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 195.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 195.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 195.8, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 196.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 196.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = BOS, trimestre = 1, compañía = AA, precio = 196.0, km = 450.8),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 196.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 196.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 196.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 196.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 196.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 196.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 196.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 196.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 197.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 197.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 197.95, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 197.99, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 198.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 198.0, km = 3867.22),
#  Vuelo(origen = MIA, destino = PHL, trimestre = 1, compañía = AA, precio = 198.47, km = 1630.93),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 198.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 198.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 199.67, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 200.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 200.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 200.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 200.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 200.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 200.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = ORD, trimestre = 1, compañía = AA, precio = 200.65, km = 2807.84),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 201.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 201.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 201.84, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 202.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 202.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 203.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 203.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 204.15, km = 3867.22),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 205.0, km = 154.56),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 205.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 205.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 205.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 205.34, km = 1671.18),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 205.35, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 206.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 206.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 206.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 206.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 207.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 207.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 208.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 208.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 209.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 209.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 209.11, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 210.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 210.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 210.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 210.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 210.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 210.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 211.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 211.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 211.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 211.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 211.91, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 212.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 212.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 212.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 212.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 212.38, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 212.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 212.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 213.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 213.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 213.21, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 214.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 214.0, km = 1671.18),
#  Vuelo(origen = SFO, destino = JFK, trimestre = 1, compañía = AA, precio = 214.64, km = 4163.46),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 215.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 215.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 215.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 215.0, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 215.08, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 215.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 215.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 216.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 216.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 216.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 216.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 217.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 217.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 217.45, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 217.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 217.5, km = 3867.22),
#  Vuelo(origen = SFO, destino = JFK, trimestre = 1, compañía = AA, precio = 218.05, km = 4163.46),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 218.36, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 218.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 218.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 219.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 219.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 219.46, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 219.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 219.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 220.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 220.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 220.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 220.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 221.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 221.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 221.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 222.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 222.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 222.67, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 223.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 223.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 223.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 223.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 223.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 223.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 223.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 224.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 224.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 224.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 224.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 224.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 224.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 225.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 225.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 225.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 225.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 225.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 225.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 225.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 225.5, km = 3867.22),
#  Vuelo(origen = DFW, destino = PHL, trimestre = 1, compañía = AA, precio = 225.62, km = 2097.83),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 226.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 226.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 226.0, km = 154.56),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 226.09, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 226.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 226.5, km = 1671.18),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 226.7, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 227.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 227.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 228.46, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 228.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 228.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 230.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 230.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 230.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 230.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 230.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 231.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 231.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 231.04, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 231.46, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 231.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 231.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 231.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 231.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 231.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 232.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 232.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 232.92, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 233.41, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 233.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 233.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 234.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 234.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 235.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 235.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 235.07, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 235.41, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 235.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 235.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 235.64, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 236.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 236.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 236.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 236.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 236.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 236.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 236.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 236.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 237.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 237.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 237.58, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 238.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 238.5, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 238.63, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 239.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 239.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 239.85, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 240.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 240.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 240.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 240.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 240.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 240.03, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 240.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 240.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 241.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 241.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 241.67, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 242.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 242.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 243.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 243.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 243.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 243.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 244.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 244.0, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 244.27, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 244.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 244.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 244.69, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 245.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 245.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 246.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 246.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 246.0, km = 154.56),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 246.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 246.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 246.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 246.5, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 246.5, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 247.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 247.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 247.1, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 248.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 248.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 249.0, km = 1671.18),
#  Vuelo(origen = MCI, destino = PHL, trimestre = 1, compañía = AA, precio = 249.0, km = 1671.18),
# ...
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 391.75, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 392.11, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 394.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 394.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 394.0, km = 154.56),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 395.64, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 399.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 399.0, km = 3867.22),
#  Vuelo(origen = LAS, destino = PHL, trimestre = 1, compañía = AA, precio = 399.45, km = 3503.36),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 401.99, km = 4058.81),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 409.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 409.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 415.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 415.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 416.04, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 417.26, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 417.94, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 420.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 422.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 422.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 422.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 422.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 423.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 425.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 425.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 427.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 427.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 430.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 431.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 431.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 433.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 433.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 433.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 433.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 434.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 434.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 434.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 436.01, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 436.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 436.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 438.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 439.07, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 443.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 443.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 444.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 444.06, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 446.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 446.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 447.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 447.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 448.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 448.0, km = 3867.22),
#  Vuelo(origen = SFO, destino = PHL, trimestre = 1, compañía = AA, precio = 451.48, km = 4058.81),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 451.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 451.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 459.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 459.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 459.97, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 460.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 461.0, km = 1671.18),
#  Vuelo(origen = AUS, destino = PHL, trimestre = 1, compañía = AA, precio = 461.99, km = 2302.3),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 465.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 466.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LGA, trimestre = 1, compañía = AA, precio = 469.0, km = 154.56),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 469.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 472.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 472.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 476.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 476.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 481.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 481.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 482.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 482.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 494.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 494.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 495.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 495.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 499.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 499.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 509.94, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 521.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 521.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 531.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 531.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 532.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 532.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 556.62, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 560.96, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 570.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 581.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 596.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 596.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 599.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 599.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 601.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 601.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 602.01, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 609.0, km = 1671.18),
#  Vuelo(origen = DFW, destino = PHL, trimestre = 1, compañía = AA, precio = 612.66, km = 2097.83),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 619.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 619.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 620.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 622.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 622.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 626.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 632.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 634.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 634.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 643.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = BOS, trimestre = 1, compañía = AA, precio = 662.5, km = 450.8),
#  Vuelo(origen = BOS, destino = PHL, trimestre = 1, compañía = AA, precio = 662.5, km = 450.8),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 672.87, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 707.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 707.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 708.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 708.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 711.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 711.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 744.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 744.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 758.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 758.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 765.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 765.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 772.0, km = 1671.18),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 776.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 776.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 778.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 781.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 781.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 790.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 790.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 795.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 795.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 800.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 800.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 804.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 804.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 808.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 808.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 815.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 815.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 820.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 858.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 858.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 869.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 869.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 880.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 880.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 890.79, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 892.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 892.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = MCI, trimestre = 1, compañía = AA, precio = 932.0, km = 1671.18),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 959.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 959.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 962.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 962.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 979.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 979.5, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 980.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 980.5, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 993.0, km = 3867.22),
#  Vuelo(origen = LAX, destino = PHL, trimestre = 1, compañía = AA, precio = 993.0, km = 3867.22),
#  Vuelo(origen = PHL, destino = LAX, trimestre = 1, compañía = AA, precio = 995.78, km = 3867.22)]
